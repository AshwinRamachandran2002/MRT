# %% [markdown]
# <a href="https://colab.research.google.com/github/AshwinRamachandran2002/MRT/blob/main/Contours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt

# %%
image=cv2.imread('/content/drive/MyDrive/MRT/taj.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
imgray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
ret, thresh0 = cv2.threshold(imgray, 127, 255, 0)
ret1,thresh1 = cv2.threshold(imgray,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(imgray,127,255,cv2.THRESH_TRUNC)
ret,thresh3 = cv2.threshold(imgray,127,255,cv2.THRESH_TOZERO)
ret,thresh4 = cv2.threshold(imgray,127,255,cv2.THRESH_TOZERO_INV)

# %%
#plt.imshow(thresh0,cmap='gray')
# plt.figure()
# plt.imshow(thresh4,cmap='gray')
# plt.figure()
# plt.imshow(thresh3,cmap='gray')
# plt.figure()
# plt.imshow(thresh1,cmap='gray')
# plt.figure()
# plt.imshow(thresh2,cmap='gray')

# %%
contours, hierarchy = cv2.findContours(thresh0,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
plt.imshow(cv2.drawContours(image, contours,-1,(255,0,0),3),cmap='gray')

# %%
x,y,w,h = cv2.boundingRect(contour[0])
contours_poly = [None]*len(contours)
boundRect = [None]*len(contours)
centers = [None]*len(contours)
radius = [None]*len(contours)
for i, c in enumerate(contours):
    contours_poly[i] = cv2.approxPolyDP(c, 3, True)
    boundRect[i] = cv2.boundingRect(contours_poly[i])
    centers[i], radius[i] = cv2.minEnclosingCircle(contours_poly[i])
drawing = np.zeros((image.shape[0], image.shape[1], 3), dtype=np.uint8)

# %%
import random as rng
for i in range(len(contours)):
        color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
        cv2.drawContours(drawing, contours_poly, i, color)
        cv2.rectangle(drawing, (int(boundRect[i][0]), int(boundRect[i][1])), \
          (int(boundRect[i][0]+boundRect[i][2]), int(boundRect[i][1]+boundRect[i][3])), color, 2)
        cv2.circle(drawing, (int(centers[i][0]), int(centers[i][1])), int(radius[i]), color, 2)
plt.imshow(drawing,cmap='gray')

# %%
plt.imshow(imgray,cmap='gray')

# %%
#gray = cv.cvtColor(imgray,cv.COLOR_BGR2GRAY)
#gray = np.float32(gray)
arrow=cv2.imread('/content/drive/MyDrive/MRT/4.png')
gray=cv2.cvtColor(arrow, cv2.COLOR_RGB2GRAY)
dst = cv2.cornerHarris(gray,5,11,0.07)
plt.imshow(dst,cmap='gray')

# %%
plt.imshow(arrow)
